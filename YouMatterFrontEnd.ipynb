# %%
from IPython.display import HTML, display

display(HTML('''
<!DOCTYPE html>
<html>
<head>
  <style>
    body {
      font-family: 'Segoe UI', sans-serif;
      background-color: #b3d9ff; /* Soft light blue background for whole page */
      margin: 0;
      padding: 0;
    }

    .header {
      background-color: #b3d9ff; /* Match the page background */
      padding: 20px;
      text-align: center;
      color: #003366;
      font-size: 32px;
      font-weight: bold;
    }

    .header img {
      height: 40px;
      vertical-align: middle;
      margin-right: 10px;
    }

    .chat-box {
      max-width: 650px;
      margin: 40px auto;
      background-color: #ffffff; /* White conversation box */
      border-radius: 15px;
      padding: 30px;
      box-shadow: 0 10px 20px rgba(0,0,0,0.15);
    }

    .messages {
      height: 300px;
      overflow-y: auto;
      padding: 15px;
      background: #d9ecff; /* Light blue message area */
      border-radius: 10px;
      border: 1px solid #cce0ff;
      margin-bottom: 15px;
    }

    .user {
      color: #004080;
      font-weight: bold;
      margin: 8px 0;
    }

    .bot {
      color: #003366;
      font-style: italic;
      margin: 8px 0;
    }

    input {
      width: 75%;
      padding: 12px;
      border: 1px solid #b3d9ff;
      border-radius: 8px;
      font-size: 15px;
      margin-right: 10px;
    }

    button {
      padding: 12px 18px;
      background-color: #3399ff;
      border: none;
      color: white;
      border-radius: 8px;
      font-size: 15px;
      cursor: pointer;
    }

    button:hover {
      background-color: #267acc;
    }

    .footer {
      text-align: center;
      color: #333;
      margin-top: 30px;
      font-size: 14px;
    }
  </style>
</head>
<body>

  <div class="header">
    YouMatter 💙 Mental Health Chatbot
    <img src="https://img.icons8.com/ios-filled/50/000000/chat.png" alt="Chat Icon"/>
  </div>

  <div class="chat-box">
    <div class="messages" id="chat">
      <div class="bot"><b>YouMatter:</b> Hi! I’m here for you. How are you feeling today?</div>
    </div>
    <div style="display: flex; margin-top: 10px;">
      <input id="userInput" placeholder="Type your message..." />
      <button onclick="sendMessage()">Send</button>
    </div>
  </div>

  <div class="footer">
    💡 Talking helps. You are heard. You are valued. You matter. 💬
  </div>

  <script>
    function sendMessage() {
      const input = document.getElementById("userInput");
      const msg = input.value.trim();
      if (!msg) return;

      const chat = document.getElementById("chat");
      chat.innerHTML += `<div class="user"><b>You:</b> ${msg}</div>`;
      chat.innerHTML += `<div class="bot"><b>YouMatter:</b> I'm here to listen. Tell me more if you'd like.</div>`;
      input.value = "";
      chat.scrollTop = chat.scrollHeight;
    }
  </script>

</body>
</html>
'''))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       background-color: #b3d9ff; /* Soft light blue background for whole page */
#       margin: 0;
#       padding: 0;
#     }
#
#     .header {
#       background-color: #b3d9ff; /* Match the page background */
#       padding: 20px;
#       text-align: center;
#       color: #003366;
#       font-size: 32px;
#       font-weight: bold;
#     }
#
#     .header img {
#       height: 40px;
#       vertical-align: middle;
#       margin-right: 10px;
#     }
#
#     .chat-box {
#       max-width: 650px;
#       margin: 40px auto;
#       background-color: #ffffff; /* White conversation box */
#       border-radius: 15px;
#       padding: 30px;
#       box-shadow: 0 10px 20px rgba(0,0,0,0.15);
#     }
#
#     .messages {
#       height: 300px;
#       overflow-y: auto;
#       padding: 15px;
#       background: #d9ecff; /* Light blue message area */
#       border-radius: 10px;
# ...

# %% [markdown]
# Features to be added:
# ~Typing animation for bot replies (e.g., "YouMatter is typing...")
#
# ~Chat bubbles with timestamps for each message
#
# ~Auto-scroll to the newest message
#
# ~Continue conversation (store messages in browser local storage or file)
#
# ~Clear chat history button
#
# ~Dark mode / light mode toggle button
#
# ~Font size & contrast adjustment by user
